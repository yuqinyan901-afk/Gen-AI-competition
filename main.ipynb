# %% [markdown]
# # **SETUP**

# %%
# install necesary packages

"""
PACKAGES TO INSTALL:
- import-ipynb
- pandas
- numpy
- langchain langchain-openai langchain-community
"""

# %pip install import-ipynb

# %pip install pandas pint numpy scikit-learn seaborn matplotlib
# %pip install langchain langchain-community langchain-openai
# %pip install python-dotenv
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: IPython in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from import-ipynb) (9.10.0)
# Requirement already satisfied: nbformat in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: decorator>=4.3.2 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from IPython->import-ipynb) (4.15.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jedi>=0.18.1->IPython->import-ipynb) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from stack_data>=0.6.0->IPython->import-ipynb) (0.2.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from nbformat->import-ipynb) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from nbformat->import-ipynb) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from nbformat->import-ipynb) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.9.4)
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting pint
#   Downloading pint-0.25.3-py3-none-any.whl.metadata (10 kB)
# Collecting numpy
#   Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting flexcache>=0.3 (from pint)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from pint) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from pint) (4.15.0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 14.4 MB/s  0:00:00 eta 0:00:01
# Downloading pint-0.25.3-py3-none-any.whl (307 kB)
# Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 13.3 MB/s  0:00:00 eta 0:00:01
# Downloading scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 12.0 MB/s  0:00:00 eta 0:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.9-cp311-cp311-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 12.9 MB/s  0:00:00m0:00:0100:01
# Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading fonttools-4.62.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 16.5 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (63 kB)
# Downloading pillow-12.2.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 13.9 MB/s  0:00:00 eta 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 13.0 MB/s  0:00:01 eta 0:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, flexparser, flexcache, cycler, scipy, pint, pandas, contourpy, scikit-learn, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [seaborn]5/17 [matplotlib]n]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 flexcache-0.3 flexparser-0.4 fonttools-4.62.1 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.4 pandas-3.0.2 pillow-12.2.0 pint-0.25.3 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain
#   Downloading langchain-1.2.18-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-core<2.0.0,>=1.3.3 (from langchain)
#   Downloading langchain_core-1.3.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph<1.2.0,>=1.1.10 (from langchain)
#   Downloading langgraph-1.1.10-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading langsmith-0.8.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_checkpoint-4.0.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.12 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading langgraph_sdk-0.3.14-py3-none-any.whl.metadata (1.7 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain)
#   Downloading orjson-3.11.9-cp311-cp311-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.33.1)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain)
#   Downloading zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.14.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from langchain-community) (2.4.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.6.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Downloading openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.4.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Downloading langchain-1.2.18-py3-none-any.whl (113 kB)
# Downloading langchain_core-1.3.3-py3-none-any.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.9/543.9 kB 19.4 MB/s  0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.10-py3-none-any.whl (173 kB)
# Downloading langgraph_checkpoint-4.0.3-py3-none-any.whl (51 kB)
# Downloading langgraph_prebuilt-1.0.13-py3-none-any.whl (37 kB)
# Downloading langgraph_sdk-0.3.14-py3-none-any.whl (97 kB)
# Downloading langsmith-0.8.3-py3-none-any.whl (399 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.8 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (604 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.7/604.7 kB 22.2 MB/s  0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 12.5 MB/s  0:00:00
# Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl (501 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.4 MB/s  0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Downloading pydantic_settings-2.14.1-py3-none-any.whl (60 kB)
# Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.5 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl (85 kB)
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Downloading openai-2.36.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.7 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl (321 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-macosx_11_0_arm64.whl (995 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 995.3/995.3 kB 16.7 MB/s  0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading orjson-3.11.9-cp311-cp311-macosx_15_0_arm64.whl (128 kB)
# Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Downloading propcache-0.5.2-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading regex-2026.4.4-cp311-cp311-macosx_11_0_arm64.whl (289 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.6/640.6 kB 18.5 MB/s  0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tqdm, tenacity, SQLAlchemy, sniffio, regex, python-dotenv, pydantic-core, propcache, ormsgpack, orjson, mypy-extensions, multidict, marshmallow, langchain-protocol, jsonpointer, jiter, httpx-sse, frozenlist, distro, annotated-types, aiohappyeyeballs, yarl, typing-inspect, tiktoken, requests-toolbelt, pydantic, jsonpatch, aiosignal, pydantic-settings, openai, langsmith, langgraph-sdk, dataclasses-json, aiohttp, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain-openai, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47/47 [langchain]47 [langchain-community]ters]
# Successfully installed SQLAlchemy-2.0.49 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-types-0.7.0 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.8.0 httpx-sse-0.4.3 jiter-0.14.0 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.2.18 langchain-classic-1.0.7 langchain-community-0.4.1 langchain-core-1.3.3 langchain-openai-1.2.1 langchain-protocol-0.0.15 langchain-text-splitters-1.1.2 langgraph-1.1.10 langgraph-checkpoint-4.0.3 langgraph-prebuilt-1.0.13 langgraph-sdk-0.3.14 langsmith-0.8.3 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 openai-2.36.0 orjson-3.11.9 ormsgpack-1.12.2 propcache-0.5.2 pydantic-2.13.4 pydantic-core-2.46.4 pydantic-settings-2.14.1 python-dotenv-1.2.2 regex-2026.4.4 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.12.0 tqdm-4.67.3 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.7.0 yarl-1.23.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/data-cleaning-agent/lib/python3.11/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load dotenv
import os, pathlib
from dotenv import load_dotenv, set_key
load_dotenv()

# Store project root in .env
PROJECT_ROOT = pathlib.Path().resolve()
ENV_PATH = PROJECT_ROOT / ".env"
if not ENV_PATH.exists():
    raise FileNotFoundError(f".env file not found.")
    
if "PROJECT_ROOT" not in os.environ:
    set_key(str(ENV_PATH), "PROJECT_ROOT", str(PROJECT_ROOT))
else:
    PROJECT_ROOT = pathlib.Path(os.environ["PROJECT_ROOT"])

# Get API Key
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    print("OpenAI API Key not found")

# %%
# Import libraries
import pandas as pd
import numpy as np

# Import route_query function
import import_ipynb
from route_query import route_query

# %% [markdown]
# # **USER ACTIONS**
# <hr>
#
# - user_load_dataset(): prompts user to pick csv to load into dataframe
# - user_actions(): prompts user to perform actions on dataframe

# %%
def user_load_dataset():
    # Check dataset folder
    datasets_path = "datasets"
    if not os.path.exists(datasets_path):
        print(f"'{datasets_path}' folder not found.")
        return
    
    print("LOAD YOUR DATASET TO GET STARTED!")
    # List existing CSVs in dataset folder
    file_paths = [f for f in os.listdir(datasets_path) if f.lower().endswith('.csv')]
    if file_paths:
        print(f"CSV files in '{datasets_path}':")
        for i, fname in enumerate(file_paths):
            print(f"{i+1}. {fname}")
    else:
        print("No CSV files found in 'datasets' folder.")
        return

    print("\nNot seeing your data? Make sure your CSV file is in 'datasets' folder")
    print("Type x to exit.")
    user_file = input("To load your dataset, input either the number or name of your desired CSV: ")

    if user_file.lower() == "x":
        print("Exiting.")
        return
    
    # Try to load by number
    if user_file.isnumeric():
        idx = int(user_file) - 1
        if 0 <= idx < len(file_paths):
            selected_file = file_paths[idx]
        else:
            print("Invalid number.")
            return
    # Not numeric try to load by name
    else:
        if user_file in file_paths:
            selected_file = user_file
        else:
            print("File not found.")
            return

    df = pd.read_csv(os.path.join(datasets_path, selected_file))
    print(f"\nLoaded '{selected_file}' with shape {df.shape}")
    print(df.head(5))
    return df

# %%
def user_actions(df):
    out_path = "datasets_out"
    while True:
        print("\nCommands:")
        print("1. View dataframe (head)")
        print("2. Output dataframe to CSV")
        print("x. Exit")
        user_query = input("\nEnter a command number or a data cleaning/query command: ")
        if user_query.lower() == "x":
            print("Exiting.")
            return df
        elif user_query == "1":
            print(df.head())
            _ = input("enter anything to continue")
        elif user_query == "2":
            if not os.path.exists(out_path):
                os.makedirs(out_path)
            out_file = os.path.join(out_path, "output.csv")
            df.to_csv(out_file, index=False)
            print(f"Dataframe saved to {out_file}")
            _ = input("enter anything to continue")
        else:
            # Calls route_query
            df = route_query(user_query, df)

# %% [markdown]
# **MAIN FUNCTION**
# -

# %%
def main():
    df = user_load_dataset()
    while df is None:
        df = user_load_dataset()
    df = user_actions(df)
    print("========== FINAL DF ==========")
    print(df)

# %% [markdown]
# **Testing**

# %%
main()
